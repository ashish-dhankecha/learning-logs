# %%
import pandas as pd
import numpy as np

# %%
email = ('Ashish@gmail.com' )

# %%
email.split("@")
# Out:
# ['Ashish', 'gmail.com']

# %%
name = pd.Series(['Ashish','Vasu','Vani',"5"])

# %%
(name)
# Out:
# 0    Ashish
# 1      Vasu
# 2      Vani
# 3         5
# dtype: object

# %%
name.str.upper()
# Out:
# 0    ASHISH
# 1      VASU
# 2      VANI
# 3         5
# dtype: object

# %%
name.str.isdigit()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# dtype: bool

# %%
name[name.str.isdigit()]
# Out:
# 3    5
# dtype: object
